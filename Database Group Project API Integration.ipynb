# %% [markdown]
# Code for writing directly to S3 Bucket

# %%
import csv
import requests
import os
import boto3
from datetime import datetime

# Function to fetch categories and save them to CSV
def fetch_and_save_categories():
    url = "https://real-time-amazon-data.p.rapidapi.com/product-category-list"
    headers = {
        "X-RapidAPI-Key": "1f8d9dea7fmsh4dee2b53eb73843p1499ffjsn4a40610e821f",
        "X-RapidAPI-Host": "real-time-amazon-data.p.rapidapi.com"
    }
    params = {}

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()
        categories = data.get("data", [])
        
        # Define CSV file name and headers
        csv_file = "amazon_AllCategories.csv"
        csv_headers = ["ID", "Name"]

        # Write data to CSV file
        with open(csv_file, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=csv_headers)
            writer.writeheader()
            for category in categories:
                writer.writerow({
                    "ID": category.get("id", ""),
                    "Name": category.get("name", "")
                })
        print("Data has been written to", csv_file)
    else:
        print("Failed to retrieve data:", response.status_code)

    return csv_file

# Main function to upload CSV file to S3
def upload_csv_to_s3(csv_file):
    # Define S3 client
    s3_client = boto3.client('s3', aws_access_key_id=os.getenv('AWS_ACCESS_KEY_ID'),
                            aws_secret_access_key=os.getenv('AWS_SECRET_ACCESS_KEY'),
                            region_name='us-east-1')
    
    # Create main bucket if it doesn't exist
    main_bucket_name = 'amazon-live-api-data-sujata'
    try:
        s3_client.head_bucket(Bucket=main_bucket_name)
    except s3_client.exceptions.ClientError as e:
    # If bucket does not exist, create it
        if e.response['Error']['Code'] == '404':
            print('Error Code is 404')
            if s3_client.meta.region_name == 'us-east-1':
                s3_client.create_bucket(Bucket=main_bucket_name)
            else:
                s3_client.create_bucket(Bucket=main_bucket_name, CreateBucketConfiguration={'LocationConstraint': s3_client.meta.region_name})
        else:
            print(e.response['Error']['Code'])
            raise e

    
    # Create subfolder with current date
    current_date = datetime.now().strftime("%Y%m%d")
    subfolder_name = current_date + "/"
    
    # Upload CSV file to S3 bucket
    object_key = subfolder_name + csv_file
    s3_client.upload_file(csv_file, main_bucket_name, object_key)

    # Remove the local CSV file after uploading to S3
    os.remove(csv_file)

    print(f"Data has been uploaded to S3: s3://{main_bucket_name}/{object_key}")

# Function to make API call and save data to CSV
def fetch_and_save_data(category_id, categories_csv_data):
    url = "https://real-time-amazon-data.p.rapidapi.com/search"
    headers = {
        "X-RapidAPI-Key": "1f8d9dea7fmsh4dee2b53eb73843p1499ffjsn4a40610e821f",
        "X-RapidAPI-Host": "real-time-amazon-data.p.rapidapi.com"
    }
    params = {
        "query": "Phone",
        "country": "US",
        "category_id": category_id
    }

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()
        products = data.get("data", {}).get("products", [])
        
        # Define CSV file name and headers
        current_date = datetime.now().strftime("%Y%m%d")
        csv_file_name = f"{current_date}_{category_id}.csv"
        csv_headers = ["ASIN", "Product Title", "Price", "Original Price", "Currency", "Star Rating", "Number of Ratings", "Product URL", "Number of Offers", "Minimum Offer Price", "Is Best Seller", "Is Amazon Choice", "Is Prime", "Climate Pledge Friendly", "Sales Volume", "Delivery","CategoryId"]

        # Write data to CSV file
        with open(csv_file_name, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=csv_headers)
            writer.writeheader()
            for product in products:
                writer.writerow({
                    "ASIN": product.get("asin", ""),
                    "Product Title": product.get("product_title", ""),
                    "Price": product.get("product_price", ""),
                    "Original Price": product.get("product_original_price", ""),
                    "Currency": product.get("currency", ""),
                    "Star Rating": product.get("product_star_rating", ""),
                    "Number of Ratings": product.get("product_num_ratings", ""),
                    "Product URL": product.get("product_url", ""),
                    "Number of Offers": product.get("product_num_offers", ""),
                    "Minimum Offer Price": product.get("product_minimum_offer_price", ""),
                    "Is Best Seller": product.get("is_best_seller", ""),
                    "Is Amazon Choice": product.get("is_amazon_choice", ""),
                    "Is Prime": product.get("is_prime", ""),
                    "Climate Pledge Friendly": product.get("climate_pledge_friendly", ""),
                    "Sales Volume": product.get("sales_volume", ""),
                    "Delivery": product.get("delivery", ""),
                    "CategoryId": category_id
                })

        # Upload CSV file to S3 bucket
        # Define S3 client
        s3_client = boto3.client('s3',
                            aws_access_key_id='Your-api-key',
                            aws_secret_access_key='Your-api-key',
                            region_name='us-east-1')
        
        # Write data to product category CSV file and upload to S3
        product_category_file_key = f"{current_date}/productdetails/{csv_file_name}"
        with open(csv_file_name, "rb") as file:
            s3_client.upload_fileobj(file, bucket_name, product_category_file_key)

        print(f"Data has been written to and uploaded to S3: s3://{bucket_name}/{product_category_file_key}")
    else:
        print("Failed to retrieve data for category:", category_id, "Status Code:", response.status_code)


if __name__ == "__main__":
    # Fetch categories and save them to CSV
    csv_file = fetch_and_save_categories()

    # Upload CSV file to S3
    upload_csv_to_s3(csv_file)

    # Read categories from S3
    bucket_name = 'amazon-live-api-data-sujata'
    current_date = datetime.now().strftime("%Y%m%d")
    categories_file_key = f"{current_date}/amazon_AllCategories.csv"
    s3_client = boto3.client('s3',
                            aws_access_key_id='Your-api-key',
                            aws_secret_access_key='Your-api-key',
                            region_name='us-east-1')
    categories_csv_data = s3_client.get_object(Bucket=bucket_name, Key=categories_file_key)
    categories = csv.DictReader(categories_csv_data['Body'].read().decode('utf-8').splitlines())
    
    # For each category now call product api and save product api details
    for row in categories:
        category_id = row["ID"]
        fetch_and_save_data(category_id, categories_csv_data)
# Out:
# Data has been written to amazon_AllCategories.csv
# Data has been uploaded to S3: s3://amazon-live-api-data-sujata/20240510/amazon_AllCategories.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_aps.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_alexa-skills.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_amazon-devices.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_live-explorations.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_amazonfresh.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_amazon-pharmacy.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_warehouse-deals.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_appliances.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_mobile-apps.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_arts-crafts.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_audible.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_automotive.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_courses.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_baby-products.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_beauty.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_stripbooks.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_popular.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_mobile.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_fashion.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_fashion-womens.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_fashion-mens.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_fashion-girls.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_fashion-boys.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_fashion-baby.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_collectibles.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_computers.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_financial.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_edu-alt-content.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_digital-music.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_electronics.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_lawngarden.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_gift-cards.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_grocery.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_handmade.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_hpc.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_local-services.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_garden.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_industrial.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_prime-exclusive.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_digital-text.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_fashion-luggage.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_luxury.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_magazines.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_movies-tv.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_mi.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_office-products.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_pets.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_luxury-beauty.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_instant-video.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_smart-home.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_software.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_sporting.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_specialty-aps-sns.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_subscribe-with-amazon.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_tools.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_toys-and-games.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_under-ten-dollars.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_videogames.csv
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/productdetails/20240510_wholefoods.csv

# %% [markdown]
# Now we will call deals API to store deals data on S3

# %%
import csv
import requests
import boto3
from datetime import datetime

def fetch_and_save_deals():
    url = "https://real-time-amazon-data.p.rapidapi.com/deals"
    headers = {
        "X-RapidAPI-Key": "Your-api-key",
        "X-RapidAPI-Host": "real-time-amazon-data.p.rapidapi.com"
    }
    params = {
        "country": "US",
        "deal_state": "ALL",
        "deal_type": "ALL"
    }

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()
        deals = data.get("data", {}).get("deals", [])

        # Define CSV file name and headers
        current_date = datetime.now().strftime("%Y%m%d")
        csv_file_name = "deals.csv"
        csv_headers = ["Deal ID", "Deal Type", "Deal Title", "Deal Photo", "Deal State", "Deal URL", "Deal Starts At", "Deal Ends At", "Deal Price Min", "Deal Price Max", "Deal Badge", "Type", "Product ASIN", "Is Prime"]

        # Write data to CSV file
        with open(csv_file_name, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=csv_headers)
            writer.writeheader()
            for deal in deals:
                writer.writerow({
                    "Deal ID": deal.get("deal_id", ""),
                    "Deal Type": deal.get("deal_type", ""),
                    "Deal Title": deal.get("deal_title", ""),
                    "Deal Photo": deal.get("deal_photo", ""),
                    "Deal State": deal.get("deal_state", ""),
                    "Deal URL": deal.get("deal_url", ""),
                    "Deal Starts At": deal.get("deal_starts_at", ""),
                    "Deal Ends At": deal.get("deal_ends_at", ""),
                    "Deal Price Min": deal.get("deal_price_min", {}).get("amount", ""),
                    "Deal Price Max": deal.get("deal_price_max", {}).get("amount", ""),
                    "Deal Badge": deal.get("deal_badge", ""),
                    "Type": deal.get("type", ""),
                    "Product ASIN": deal.get("product_asin", ""),
                    "Is Prime": deal.get("is_prime", "")
                })

        # Upload CSV file to S3 bucket
        s3_client = boto3.client('s3',
                                 aws_access_key_id='Your-api-key',
                                 aws_secret_access_key='Your-api-key',
                                 region_name='us-east-1')  
        
        # Create deals folder if it doesn't exist
        folder_key = f"{current_date}/deals"
        # s3_client.put_object(Bucket=bucket_name, Key=folder_key)
        
        # Upload the CSV file to S3
        object_key = f"{folder_key}/{csv_file_name}"
        with open(csv_file_name, "rb") as file:
            s3_client.upload_fileobj(file, bucket_name, object_key)

        print(f"Data has been written to and uploaded to S3: s3://{bucket_name}/{object_key}")
    else:
        print("Failed to retrieve deals. Status Code:", response.status_code)

if __name__ == "__main__":
    fetch_and_save_deals()
# Out:
# Data has been written to and uploaded to S3: s3://amazon-live-api-data-sujata/20240510/deals/deals.csv
